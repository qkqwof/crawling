# %% [markdown]
# ## 크롤링

# %%
# 라이브러리 임포트
import requests
from bs4 import BeautifulSoup
#웹페이지 가져오기
res = 
#웹페이지 파싱하기
soup = 
#필요한 데이터 추출하기
mydata = 
#추출한 데이터 활용하기
print()
# Out:
#   File "<ipython-input-1-988b00a8b5d3>", line 5
#     res =
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.필요 라이브러리
# - requests
#     - 웹페이지 가져오기 라이브러리
# - bs4(BeautifulSoup)
#     - 웹페이지 분석(크롤링) 라이브러리

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# #### 2. 웹페이지 가져오기
# - res.content 확인해보기

# %%
res = requests.get("https://news.v.daum.net/v/20210504133808489")
res.content # 특정 페이지의 html 태그
# Out:
# b'<!doctype html>\n<html lang="ko"> \n <head data-cloud-area="head"> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=edge"> \n  <style>\n            @import url(\'//t1.daumcdn.net/harmony_static/cloud/page/3e96c93f90d4df7aca693bfb2ba2ea76d2d14d92.css\');\n            @import url(\'//t1.daumcdn.net/harmony_static/cloud/2021/05/03/common.4fa0ea63845693bada8b.css\')\n        </style> \n  <style>\n            /* \xeb\x8b\xa4\xec\x9d\x8c \xec\xb9\xb4\xed\x8e\x98 \xec\x86\x8c\xec\x85\x9c \xec\x89\x90\xec\x96\xb4 \xec\x9e\x84\xec\x8b\x9c \xeb\xb9\x84\xed\x99\x9c\xec\x84\xb1\xed\x99\x94 */\n            .list_sns li:nth-child(6) {\n                display: none;\n            }\n        </style> \n  <meta property="mccp:docId" content="ctSl8aw9sC"> \n  <meta property="og:site_name" content="\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4"> \n  <meta property="og:title" content="\'\xeb\x82\x9a\xec\x8b\x9c\xea\xbe\xbc \xed\x95\x9c\xea\xb0\x95 \xeb\xaa\xa9\xea\xb2\x
# ...

# %% [markdown]
# #### IP Address : ex) 123.123.11.51
# - 사용하기는 번거로움...
# - 따라서 정해진 이름을 치면 IP address를 찾아서 웹 브라우저로 연결해줌

# %% [markdown]
# #### 3. 웹페이지 파싱하기
# - 파싱(parsing)이란?
#     - 문자열의 의미를 분석하는 것

# %%
soup = BeautifulSoup(res.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head data-cloud-area="head">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <style>
#             @import url('//t1.daumcdn.net/harmony_static/cloud/page/3e96c93f90d4df7aca693bfb2ba2ea76d2d14d92.css');
#             @import url('//t1.daumcdn.net/harmony_static/cloud/2021/05/03/common.4fa0ea63845693bada8b.css')
#         </style>
# <style>
#             /* 다음 카페 소셜 쉐어 임시 비활성화 */
#             .list_sns li:nth-child(6) {
#                 display: none;
#             }
#         </style>
# <meta content="ctSl8aw9sC" property="mccp:docId"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="'낚시꾼 한강 목격담' 경찰 &quot;주차장 접촉사고, 경찰차 2대 출동&quot;" property="og:title"/>
# <meta content="20210504133807" property="og:regDate"/>
# <meta content="article" property="og:type"/>
# <meta content="https://news.v.daum.net/v/ctSl8aw9sC" property="og:url"/>
# ...

# %% [markdown]
# #### 4.필요한 데이터 추출하기
# > 이 부분이 크롤링 핵심!!
# - soup.find()함수로 원하는 부분을 지정하면 됨
# - 변수.get_text() 함수로 추출한 부분을 가져올 수 있다.

# %%
mydata = soup.find("title")
print(mydata.get_text())
# Out:
# '낚시꾼 한강 목격담' 경찰 "주차장 접촉사고, 경찰차 2대 출동"
